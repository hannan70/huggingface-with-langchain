# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')
os.environ['HUGGINGFACE_TOKEN'] = os.getenv('HUGGINGFACE_TOKEN')
os.environ['LANGSMITH_API_KEY'] = os.getenv('LANGSMITH_API_KEY')
os.environ['LANGCHAIN_PROJECT'] = os.getenv('LANGCHAIN_PROJECT')
os.environ['LANGSMITH_TRACING'] = 'true'

# %%
from langchain_groq import ChatGroq
from langchain_community.document_loaders import WebBaseLoader
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

# %%
# from langchain_groq import ChatGroq
# from langchain_community.document_loaders import WebBaseLoader
# from langchain_huggingface import HuggingFaceEmbeddings
# from langchain_text_splitters import RecursiveCharacterTextSplitter
# from langchain_community.vectorstores import FAISS
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from langchain.chains import create_retrieval_chain
# from langchain.chains.combine_documents import create_stuff_documents_chain


# # data ingestion
# web_loader = WebBaseLoader(web_path="https://www.geeksforgeeks.org/convolutional-neural-network-cnn-in-machine-learning/")
# docs = web_loader.load()


# # new doc -> text split -> embedding -> store vectore db
# text_splitters = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
# splits = text_splitters.split_documents(docs)

# # creatie embedding
# embeddings = HuggingFaceEmbeddings(model='all-MiniLM-L6-v2')

# vector_store = FAISS.from_documents(docs, embedding=embeddings)

# prompt = ChatPromptTemplate.from_template(
#     """ 
#     Answer the following question based on the provided context:
#     <context>
#     {context}
#     </context>

#     """
# )

# llm = ChatGroq(model="llama3-70b-8192")

# document_chain = create_stuff_documents_chain(llm, prompt)


# retriver = vector_store.as_retriever()
# retriver_chain = create_retrieval_chain(retriver, document_chain)


# response = retriver_chain.invoke({"input": "what is convolutional neural network (CNN)"})
# response['answer']

# %%
# data ingestion
web_loader = WebBaseLoader(web_path="https://www.geeksforgeeks.org/convolutional-neural-network-cnn-in-machine-learning/")
docs = web_loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://www.geeksforgeeks.org/convolutional-neural-network-cnn-in-machine-learning/', 'title': 'Convolutional Neural Network (CNN) in Machine Learning | GeeksforGeeks', 'description': 'Your All-in-One Learning Portal: GeeksforGeeks is a comprehensive educational platform that empowers learners across domains-spanning computer science and programming, school education, upskilling, commerce, software tools, competitive exams, and more.', 'language': 'en-US'}, page_content="\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nConvolutional Neural Network (CNN) in Machine Learning | GeeksforGeeks\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\nCoursesDSA to DevelopmentGet IBM CertificationNewly Launched!Master Django FrameworkBecome AWS CertifiedFor Working ProfessionalsInterview 101: DSA & System DesignData Science Training ProgramJAVA Backend D
# ...

# %%
# new doc -> text split -> embedding -> store vectore db
text_splitters = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitters.split_documents(docs)
splits[:10]
# Out:
# [Document(metadata={'source': 'https://www.geeksforgeeks.org/convolutional-neural-network-cnn-in-machine-learning/', 'title': 'Convolutional Neural Network (CNN) in Machine Learning | GeeksforGeeks', 'description': 'Your All-in-One Learning Portal: GeeksforGeeks is a comprehensive educational platform that empowers learners across domains-spanning computer science and programming, school education, upskilling, commerce, software tools, competitive exams, and more.', 'language': 'en-US'}, page_content='Convolutional Neural Network (CNN) in Machine Learning | GeeksforGeeks\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content'),
# ...

# %%
# creatie embedding
embeddings = HuggingFaceEmbeddings(model='all-MiniLM-L6-v2')

# %%
vector_store = FAISS.from_documents(docs, embedding=embeddings)

# %%
vector_store.similarity_search("what is convolution neural network?")
# Out:
# [Document(id='90327123-7cf9-4ba1-b2de-696ffa4d5a77', metadata={'source': 'https://www.geeksforgeeks.org/convolutional-neural-network-cnn-in-machine-learning/', 'title': 'Convolutional Neural Network (CNN) in Machine Learning | GeeksforGeeks', 'description': 'Your All-in-One Learning Portal: GeeksforGeeks is a comprehensive educational platform that empowers learners across domains-spanning computer science and programming, school education, upskilling, commerce, software tools, competitive exams, and more.', 'language': 'en-US'}, page_content="\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nConvolutional Neural Network (CNN) in Machine Learning | GeeksforGeeks\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\nCoursesDSA to DevelopmentGet IBM CertificationNewly Launched!Master Django FrameworkBecome AWS CertifiedFor Working ProfessionalsInterview 101: DSA & System Design
# ...

# %%
prompt = ChatPromptTemplate.from_template(
    """ 
    You are an expert AI assistant. Answer the following question based only on the context below.
    
    <context>
    {context}
    </context>

    Question: {input}

    Answer in a clear, concise way.

    """
)

llm = ChatGroq(model="llama3-70b-8192")

# %%
document_chain = create_stuff_documents_chain(llm, prompt)
document_chain
# Out:
# RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableLambda(format_docs)
# }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
# | ChatPromptTemplate(input_variables=['context', 'input'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'input'], input_types={}, partial_variables={}, template=' \n    You are an expert AI assistant. Answer the following question based only on the context below.\n\n    <context>\n    {context}\n    </context>\n\n    Question: {input}\n\n    Answer in a clear, concise way.\n\n    '), additional_kwargs={})])
# | ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000002823C0B6CD0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000002823C0B7750>, model_name='llama3-70b-8192', model_kwargs={}, groq_api_key=SecretStr('**********'))
# ...

# %%
retriver = vector_store.as_retriever()
retriver_chain = create_retrieval_chain(retriver, document_chain)

# %%
retriver_chain
# Out:
# RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableBinding(bound=RunnableLambda(lambda x: x['input'])
#            | VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x000002823CA5C750>, search_kwargs={}), kwargs={}, config={'run_name': 'retrieve_documents'}, config_factories=[])
# })
# | RunnableAssign(mapper={
#     answer: RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#               context: RunnableLambda(format_docs)
#             }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
# ...

# %%
response = retriver_chain.invoke({"input": "what is convolutional neural network (CNN)"})
response['answer']
# Out:
# 'A Convolutional Neural Network (CNN) is a specialized class of neural networks designed to process grid-like data, particularly well-suited for image recognition and processing tasks.'

# %%
response
# Out:
# {'input': 'what is convolutional neural network (CNN)',
# ...
